# %%
# used for data manipulation and analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the data
sales = pd.read_csv('sales.csv')

# %%
#checking the shape
print("This dataset has\nRows: {}\nColumns: {}".format(sales.shape[0],sales.shape[1]))
# Out:
# This dataset has
# Rows: 9800
# Columns: 18

# %%
#printing top 10 rows
sales.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 6       7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 7       8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 8       9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 9      10  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City       State  \
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
##computes and displays summary statistics
round(sales.describe(),0)
# Out:
#        Row ID  Postal Code    Sales
# count  9800.0       9789.0   9800.0
# mean   4900.0      55273.0    231.0
# std    2829.0      32041.0    627.0
# min       1.0       1040.0      0.0
# 25%    2451.0      23223.0     17.0
# 50%    4900.0      58103.0     54.0
# 75%    7350.0      90008.0    211.0
# max    9800.0      99301.0  22638.0

# %%
round(sales.describe().T,0)
# Out:
#               count     mean      std     min      25%      50%      75%  \
# Row ID       9800.0   4900.0   2829.0     1.0   2451.0   4900.0   7350.0
# Postal Code  9789.0  55273.0  32041.0  1040.0  23223.0  58103.0  90008.0
# Sales        9800.0    231.0    627.0     0.0     17.0     54.0    211.0
#
#                  max
# Row ID        9800.0
# Postal Code  99301.0
# Sales        22638.0

# %%
NumericAttribute = round(sales.describe().T,0)
NumericAttribute
NumericAttribute.to_csv("NumericAttribute.csv")

# %%
#plot the whole data
sales.hist(figsize = (20,15))
plt.show()

# %%
sales.corr()
# Out:
#                Row ID  Postal Code     Sales
# Row ID       1.000000     0.013645  0.001151
# Postal Code  0.013645     1.000000 -0.024067
# Sales        0.001151    -0.024067  1.000000

# %%
sns.heatmap(sales.corr(),annot=True)

# %%
#printing column name
sales.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
#renaming unknown column to others
sales.rename(columns = {'Row ID': 'Row_id', 'Order ID' : 'Order_id', 'Order Date' : 'Order_date' ,'Ship Date' : 'Ship_date', 'Ship Mode' : 'Ship_mode', 'Customer ID' : 'Cid', 'Customer Name' : 'Customer_name', 'Postal Code' : 'Postal_code', 'Product ID' : 'Pid', 'Product Name' : 'Product_name'}, inplace=True)

# %%
#rechecking columns name after renaming
sales.columns
# Out:
# Index(['Row_id', 'Order_id', 'Order_date', 'Ship_date', 'Ship_mode', 'Cid',
#        'Customer_name', 'Segment', 'Country', 'City', 'State', 'Postal_code',
#        'Region', 'Pid', 'Category', 'Sub-Category', 'Product_name', 'Sales'],
#       dtype='object')

# %%
#checking if dataset has any duplicate rows
sales.duplicated().sum()
# Out:
# 0

# %%
## check null values
sales.isnull()
# Out:
#       Row_id  Order_id  Order_date  Ship_date  Ship_mode    Cid  \
# 0      False     False       False      False      False  False
# 1      False     False       False      False      False  False
# 2      False     False       False      False      False  False
# 3      False     False       False      False      False  False
# 4      False     False       False      False      False  False
# ...      ...       ...         ...        ...        ...    ...
# 9795   False     False       False      False      False  False
# 9796   False     False       False      False      False  False
# 9797   False     False       False      False      False  False
# 9798   False     False       False      False      False  False
# 9799   False     False       False      False      False  False
#
#       Customer_name  Segment  Country   City  State  Postal_code  Region  \
# 0             False    False    False  False  False        False   False
# ...

# %%
#check null values in entire dataset
sales.isnull().sum().sum()
# Out:
# 11

# %%
sales.dropna(inplace = True)

# %%
sales.isnull().sum().sum()
# Out:
# 0

# %%
sales.dtypes
# Out:
# Row_id             int64
# Order_id          object
# Order_date        object
# Ship_date         object
# Ship_mode         object
# Cid               object
# Customer_name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal_code      float64
# Region            object
# Pid               object
# Category          object
# Sub-Category      object
# Product_name      object
# Sales            float64
# dtype: object

# %%
# To read the data as a time series
from datetime import datetime
dateparse = lambda x: datetime.strptime(x, '%d/%m/%Y')

# %%
#Convert Order Date to Datetime
sales['Order_date']= pd.to_datetime(sales['Order_date'])
sales['Ship_date']= pd.to_datetime(sales['Ship_date'])
#Create a Month Year Column
sales['Year Month'] = sales['Order_date'].apply(lambda x: x.strftime('%Y-%m'))

# %%
sales_of_trend = pd.DataFrame(sales.groupby('Year Month').sum()['Sales'].reset_index())
sales_of_trend
# Out:
#    Year Month       Sales
# 0     2015-01  28828.2540
# 1     2015-02  12588.4840
# 2     2015-03  54027.6920
# 3     2015-04  24710.0160
# 4     2015-05  29520.4900
# 5     2015-06  29181.3346
# 6     2015-07  35194.5580
# 7     2015-08  37349.2655
# 8     2015-09  65956.3998
# 9     2015-10  34561.9470
# 10    2015-11  64369.4565
# 11    2015-12  63568.3107
# 12    2016-01  29347.3864
# 13    2016-02  20728.3520
# 14    2016-03  34489.6776
# 15    2016-04  38056.9685
# 16    2016-05  30761.5585
# 17    2016-06  28515.9082
# 18    2016-07  27858.1100
# 19    2016-08  44672.0300
# 20    2016-09  65352.9970
# 21    2016-10  31631.8890
# 22    2016-11  50009.1450
# 23    2016-12  52891.8832
# 24    2017-01  36375.8740
# 25    2017-02  48907.5900
# 26    2017-03  48990.1410
# 27    2017-04  42368.0480
# 28    2017-05  64836.2518
# 29    2017-06  36129.9310
# 30    2017-07  41761.9430
# 31    2017-08  45766.8144
# 32    2017-09  40692.3063
# 33    2017-10  52156.9580
# ...

# %%
#2nd method converting the dates from string to date format
sales["Order_date"] = pd.to_datetime(sales["Order_date"], dayfirst = True).dt.date
sales["Ship_date"] = pd.to_datetime(sales["Ship_date"], dayfirst = True).dt.date

# %%
sales.dtypes
# Out:
# Row_id                    int64
# Order_id                 object
# Order_date       datetime64[ns]
# Ship_date        datetime64[ns]
# Ship_mode              category
# Cid                      object
# Customer_name          category
# Segment                category
# Country                category
# City                   category
# State                  category
# Postal_code             float64
# Region                 category
# Pid                    category
# Category               category
# Sub-Category           category
# Product_name           category
# Sales                   float64
# Year Month               object
# dtype: object

# %%
sales["Ship_mode"] = sales["Ship_mode"].astype("category")
sales["Customer_name"] = sales["Customer_name"].astype("category")
sales["Segment"] = sales["Segment"].astype("category")
sales["Country"] = sales["Country"].astype("category")
sales["City"] = sales["City"].astype("category")
sales["State"] = sales["State"].astype("category")
sales["Region"] = sales["Region"].astype("category")
sales["Pid"] = sales["Pid"].astype("category")
sales["Category"] = sales["Category"].astype("category")
sales["Sub-Category"] = sales["Sub-Category"].astype("category")
sales["Product_name"] = sales["Product_name"].astype("category")
sales["Cid"] = sales["Cid"].astype("category")
sales["Order_id"] = sales["Order_id"].astype("category")
sales["Sales"] = sales["Sales"].astype("int")

# %%
sales.dtypes
# Out:
# Row_id                    int64
# Order_id               category
# Order_date       datetime64[ns]
# Ship_date        datetime64[ns]
# Ship_mode              category
# Cid                    category
# Customer_name          category
# Segment                category
# Country                category
# City                   category
# State                  category
# Postal_code             float64
# Region                 category
# Pid                    category
# Category               category
# Sub-Category           category
# Product_name           category
# Sales                     int64
# Year Month               object
# dtype: object

# %%
plt.figure( figsize =(20,15))
plt.xticks(rotation = 'vertical', size =10)
plt.plot(sales_of_trend['Year Month'], sales_of_trend['Sales'], color = 'purple')
plt.title('SALES TREND (2015 - 2018)')
plt.ylabel('Sales')
plt.xlabel('Year Month')
plt.show()

# %%
#most selling products which is related to highest to lowest 
most_selling_product = sales['Product_name'].value_counts().head(20)
most_selling_product
# Out:
# Staple envelope                                               47
# Staples                                                       46
# Easy-staple paper                                             44
# Avery Non-Stick Binders                                       20
# Staple remover                                                18
# Staples in misc. colors                                       18
# Storex Dura Pro Binders                                       17
# KI Adjustable-Height Table                                    17
# Staple-based wall hangings                                    16
# Logitech 910-002974 M325 Wireless Mouse for Web Scrolling     15
# Situations Contoured Folding Chairs, 4/Set                    15
# Global Wood Trimmed Manager's Task Chair, Khaki               14
# Global High-Back Leather Tilter, Burgundy                     14
# GBC Premium Transparent Covers with Diagonal Lined Pattern    14
# ...

# %%
#top 30 poduct of sales with amount, starting from highest
product_sales = pd.DataFrame(sales.groupby('Product_name').sum()['Sales'])
product_sales = product_sales.sort_values('Sales', ascending = False)
product_sales[:30]
# Out:
#                                                     Sales
# Product_name
# Canon imageCLASS 2200 Advanced Copier               61595
# Fellowes PB500 Electric Punch Plastic Comb Bind...  27446
# Cisco TelePresence System EX90 Videoconferencin...  22638
# HON 5400 Series Task Chairs for Big and Tall        21866
# GBC DocuBind TL300 Electric Binding System          19815
# GBC Ibimaster 500 Manual ProClick Binding System    19019
# Hewlett Packard LaserJet 3310 Copier                18832
# HP Designjet T520 Inkjet Large Format Printer -...  18372
# GBC DocuBind P400 Electric Binding System           17962
# High Speed Automatic Electric Letter Opener         17029
# Lexmark MX611dhe Monochrome Laser Printer           16826
# Martin Yale Chadless Opener Electric Letter Opener  16654
# Ibico EPK-21 Electric Binding System                15873
# 3D Systems Cube Printer, 2nd Generation, Magenta    14298
# Samsung Galaxy Mega 6.3                             13938
# ...

# %%
#which method is mostly peffered for shipping
preferred_shipping = sales.groupby('Ship_mode').sum()['Sales']
preferred_shipping
# Out:
# Ship_mode
# First Class        344671
# Same Day           124907
# Second Class       448054
# Standard Class    1329194
# Name: Sales, dtype: int64

# %%
sns.countplot(sales['Ship_mode'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#count numcer of product with category of each product 
category= sales.groupby(sales['Category']).count()['Sales']
category
# Out:
# Category
# Furniture          2076
# Office Supplies    5903
# Technology         1810
# Name: Sales, dtype: int64

# %%
sns.countplot(sales['Category'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#count sales of product according to sub categories
sub_category= sales.groupby(sales['Sub-Category']).count()['Sales']
sub_category
# Out:
# Sub-Category
# Accessories     754
# Appliances      458
# Art             784
# Binders        1492
# Bookcases       225
# Chairs          606
# Copiers          66
# Envelopes       247
# Fasteners       214
# Furnishings     931
# Labels          357
# Machines        115
# Paper          1336
# Phones          875
# Storage         831
# Supplies        184
# Tables          314
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=[16,6])
sns.countplot(sales['Sub-Category'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# most category is the most profitable
category_sales= sales.groupby(sales['Category']).sum()['Sales'].reset_index()
category_sales= category_sales.sort_values('Sales', ascending = False)
category_sales
# Out:
#           Category   Sales
# 2       Technology  824542
# 0        Furniture  722356
# 1  Office Supplies  699928

# %%
#top 30 cities with the highest sale
city_count= sales['City'].value_counts()
city_count = city_count.sort_values(ascending = False)
city_count.head(20)
# Out:
# New York City    891
# Los Angeles      728
# Philadelphia     532
# San Francisco    500
# Seattle          426
# Houston          374
# Chicago          308
# Columbus         221
# San Diego        170
# Springfield      161
# Dallas           156
# Jacksonville     125
# Detroit          115
# Newark            92
# Jackson           82
# Columbia          81
# Richmond          81
# Aurora            68
# Phoenix           63
# Arlington         60
# Name: City, dtype: int64

# %%
# Clustered Bar Chart 
plt.figure(figsize=[8,6])
ax = sns.barplot(data = sales, x = 'Sales', y = 'City', hue = 'Year Month')
ax.legend(loc = 10, ncol = 6, framealpha = 4, title = 'Sales')
plt.title('Average of Sales')
plt.xlabel('sales')
plt.ylabel('City');

# %%
#define sapmling strategy

# !pip install imblearn

# %% [markdown]
# Now i am going to scaling which means:- This is a technique to standardize the independent variables present in the data in a fixed range. It is performed during the data pre-processing to handle highly varying values or units. So, I use Feature Scaling to bring all values to the same magnitudes, like to say,to tackle the issues

# %%
# drop uneeded columns
sales.drop(['Order_date','Ship_date'],inplace = True, axis=1)
sales.columns.tolist()
# Out:
# ['Row_id',
#  'Order_id',
#  'Ship_mode',
#  'Cid',
#  'Customer_name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Region',
#  'Pid',
#  'Category',
#  'Sub-Category',
#  'Product_name',
#  'Sales',
#  'Year Month']

# %%
#Separating the independent variables and dependent variables
x = sales.iloc[:,:-1]
y = sales.iloc[:,-1]

# %%
x.head(3)
# Out:
#    Row_id        Order_id Order_date  Ship_date     Ship_mode       Cid  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11  Second Class  CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11  Second Class  CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-06-16  Second Class  DV-13045
#
#      Customer_name    Segment        Country         City       State Region  \
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky  South
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky  South
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California   West
#
#                Pid         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product_name  Sales
# 0                  Bush Somerset Collection Bookcase    261
# ...

# %%
#this is showing to target variable
y.head()
# Out:
# 0    2017-08
# 1    2017-08
# 2    2017-12
# 3    2016-11
# 4    2016-11
# Name: Year Month, dtype: object

# %%
# Split train-test data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30,random_state=3)#(use random state to fix train set)

# %%
# oversampling
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='minority',random_state=5)

# %%
#fit and apply the transform
x_train_over, y_train_over = oversample.fit_resample(x_train, y_train)

# %%
print("after oversampling:")
y_train_over.value_counts()
# Out:
# after oversampling:
# 2018-09    265
# 2016-01    265
# 2018-11    249
# 2018-12    222
# 2018-03    214
# 2016-09    194
# 2017-11    192
# 2016-11    190
# 2017-12    186
# 2015-11    182
# 2018-08    181
# 2017-05    177
# 2015-12    175
# 2018-02    175
# 2018-10    172
# 2016-12    172
# 2017-08    171
# 2018-05    168
# 2018-07    165
# 2015-09    164
# 2018-06    163
# 2017-10    162
# 2018-04    160
# 2018-01    154
# 2017-09    144
# 2017-07    137
# 2017-04    127
# 2017-03    127
# 2017-06    126
# 2016-08    119
# 2015-07    119
# 2016-05    115
# 2016-10    114
# 2016-06    112
# 2017-01    112
# 2016-04    110
# 2015-03    108
# 2016-03    103
# 2015-05    100
# 2015-06     99
# 2015-01     91
# 2015-08     91
# 2015-10     90
# 2017-02     87
# 2015-04     87
# 2016-07     86
# 2016-02     70
# 2015-02     64
# Name: Year Month, dtype: int64

# %%
x_train_over.duplicated().sum()
# Out:
# 204

# %%
sales_prepro = sales.copy() # This is relate to preprocessing metghod

# %%
# Scalling
from sklearn.preprocessing import MinMaxScaler
numerical = ['Sales']

scaler = MinMaxScaler()
sales_prepro[numerical] = scaler.fit_transform(sales_prepro[numerical])

# %% [markdown]
# Now, my data has been scaled to MinMaxScalling for numerical attributes, which converts the data to have a range between 0 and 1. That would help to make the data well-prepared for the model.

# %%
sales_prepro.sample(3)##returns a list with a randomly selection of a specified number of items from a sequnce
# Out:
#       Row_id        Order_id       Ship_mode       Cid    Customer_name  \
# 4094    4095  CA-2016-102491  Standard Class  KW-16435  Katrina Willman
# 2893    2894  CA-2018-139913  Standard Class  JC-16105  Julie Creighton
# 7686    7687  CA-2017-169838  Standard Class  BB-11545    Brenda Bowman
#
#         Segment        Country       City     State   Region              Pid  \
# 4094   Consumer  United States   Florence  Kentucky    South  TEC-AC-10003289
# 2893  Corporate  United States  Rochester  New York     East  OFF-PA-10002479
# 7686  Corporate  United States    Jackson  Michigan  Central  FUR-TA-10001095
#
#              Category Sub-Category  \
# 4094       Technology  Accessories
# 2893  Office Supplies        Paper
# 7686        Furniture       Tables
#
#                                            Product_name     Sales Year Month
# 4094  Anker Ultra-Slim Mini Bluetooth 3.0 Wireless K...  0.003490    2016-08
# ...

# %%
# Create dummy variables: this is the easiest way to convert categorical to numeric data.
sales_prepro = pd.get_dummies(sales_prepro)

# %%
sales_prepro
# Out:
#       Row_id     Sales  Order_id_CA-2015-100006  Order_id_CA-2015-100090  \
# 0          1  0.011529                        0                        0
# 1          2  0.032291                        0                        0
# 2          3  0.000618                        0                        0
# 3          4  0.042274                        0                        0
# 4          5  0.000972                        0                        0
# ...      ...       ...                      ...                      ...
# 9795    9796  0.000133                        0                        0
# 9796    9797  0.000442                        0                        0
# 9797    9798  0.010381                        0                        0
# 9798    9799  0.001149                        0                        0
# 9799    9800  0.000442                        0                        0
#
#       Order_id_CA-2015-100293  Order_id_CA-2015-100328  \
# ...

# %%
sales_prepro.shape
# Out:
# (9789, 10869)

# %%
# import some classification models
from sklearn.ensemble import RandomForestClassifier

from sklearn.linear_model import LogisticRegression

# import needed functions

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
#Separating the independent variables and dependent variables
x = sales_prepro.iloc[:,:-1]
y = sales_prepro.iloc[:,-1]

# %%
x.head(3)
# Out:
#    Row_id     Sales  Order_id_CA-2015-100006  Order_id_CA-2015-100090  \
# 0       1  0.011529                        0                        0
# 1       2  0.032291                        0                        0
# 2       3  0.000618                        0                        0
#
#    Order_id_CA-2015-100293  Order_id_CA-2015-100328  Order_id_CA-2015-100363  \
# 0                        0                        0                        0
# 1                        0                        0                        0
# 2                        0                        0                        0
#
#    Order_id_CA-2015-100391  Order_id_CA-2015-100678  Order_id_CA-2015-100706  \
# 0                        0                        0                        0
# 1                        0                        0                        0
# 2                        0                        0                        0
#
# ...

# %%
# random state: 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30,random_state=3)
#The data has been split into training and testing parts of the features and 
#the label with a test size of 30% and without a random state with the next runs.
# This happened by using the train_test_split function.

# %%
x_train.head(3)
# Out:
#       Row_id     Sales  Order_id_CA-2015-100006  Order_id_CA-2015-100090  \
# 6457    6458  0.000663                        0                        0
# 5345    5346  0.032026                        0                        0
# 670      671  0.004771                        0                        0
#
#       Order_id_CA-2015-100293  Order_id_CA-2015-100328  \
# 6457                        0                        0
# 5345                        0                        0
# 670                         0                        0
#
#       Order_id_CA-2015-100363  Order_id_CA-2015-100391  \
# 6457                        0                        0
# 5345                        0                        0
# 670                         0                        0
#
#       Order_id_CA-2015-100678  Order_id_CA-2015-100706  ...  \
# 6457                        0                        0  ...
# 5345                        0                        0  ...
# ...

# %%
#Models
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
model=LogisticRegression()
model.fit(x_train,y_train)#takes the training data as arguments
predict_logistic=model.predict(x_test)
predict_logistic
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
y_test
# Out:
# 1928    0
# 6248    0
# 5725    0
# 2896    0
# 7668    0
#        ..
# 5447    0
# 4723    0
# 2667    0
# 2919    0
# 7998    0
# Name: Year Month_2018-12, Length: 2937, dtype: uint8

# %%
confusion_matrix_logistic=confusion_matrix(y_test,predict_logistic)#takes in the list of actual labels, the list of predicted labels, and an optional argument to specify the order of the labels
logistic_acc=accuracy_score(y_test,predict_logistic)*100
print("accuracy of logistic regression:",round(logistic_acc,2),"%")
# Out:
# accuracy of logistic regression: 97.17 %

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
model = knn.fit(x_train,y_train)
pred_k=model.predict(x_test)
knn_acc=accuracy_score(y_test,pred_k)*100
print("acuracy of KNN:", round(knn_acc,2),"%")
# Out:
# acuracy of KNN: 96.77 %

# %%
from sklearn.naive_bayes import GaussianNB
GNB=GaussianNB()
model2=GNB.fit(x_train,y_train)
pred_GNB=model2.predict(x_test)
GNB_acc=accuracy_score(y_test,pred_GNB)*100
print("accuracy of KNN:",round(GNB_acc,2),"%")
# Out:
# accuracy of KNN: 16.51 %

# %%
from sklearn.ensemble import RandomForestClassifier
RFC=RandomForestClassifier()
model3=RFC.fit(x_train,y_train)
pred_RFC=model3.predict(x_test)
RFC_acc=accuracy_score(y_test,pred_RFC)*100
print("accuracy of knn:",round(RFC_acc,2),"%")
# Out:
# accuracy of knn: 97.85 %

# %% [markdown]
# As a result, I observe that Random Forest Classifier over fits the train set, and gives a 97.85% accuracy on train data.

# %%
sales_prepro = pd.DataFrame
import warnings
warnings.filterwarnings('ignore')

# %%
#comparing accuracy
labels = ["Logistic Regression" , "KNN" , "Naive Bayes" , "random Forest"]
x = [logistic_acc , knn_acc , GNB_acc ,RFC_acc]
eval_frame = pd.DataFrame()
eval_frame['Model'] = labels
eval_frame['train_test_split'] = x
eval_frame
# Out:
#                  Model  train_test_split
# 0  Logistic Regression         97.173987
# 1                  KNN         96.765407
# 2          Naive Bayes         16.513449
# 3        random Forest         97.854954

# %% [markdown]
# ARIMA Model

# %%
from statsmodels.tsa.arima_model import ARIMA
# 0,1,1 ARIMA Model
model = ARIMA(sales_prepro.Sales, order=(0,1,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Sales   No. Observations:                 9788
# Model:                 ARIMA(0, 1, 1)   Log Likelihood               21237.460
# Method:                       css-mle   S.D. of innovations              0.028
# Date:                Mon, 21 Mar 2022   AIC                         -42468.921
# Time:                        16:39:47   BIC                         -42447.354
# Sample:                             1   HQIC                        -42461.613
#
# ...

# %%
model = ARIMA(sales_prepro.Sales, order=(1,1,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Sales   No. Observations:                 9788
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               21237.823
# Method:                       css-mle   S.D. of innovations              0.028
# Date:                Mon, 21 Mar 2022   AIC                         -42467.647
# Time:                        16:39:14   BIC                         -42438.891
# Sample:                             1   HQIC                        -42457.903
#
# ...

# %%
model = ARIMA(sales_prepro.Sales, order=(5,1,2))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Sales   No. Observations:                 9788
# Model:                 ARIMA(5, 1, 2)   Log Likelihood               21230.987
# Method:                       css-mle   S.D. of innovations              0.028
# ...
